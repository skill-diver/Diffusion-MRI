# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! unzip  /content/drive/MyDrive/BRATS_2020/archive.zip -d /content/drive/MyDrive/BRATS_2020/brats2020/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/BRATS_2020/brats2020/BraTS2020_training_data/content/data/volume_70_slice_63.h5
#   inflating: /content/drive/MyDrive/BRATS_2020/brats2020/BraTS2020_training_data/content/data/volume_70_slice_64.h5
#   inflating: /content/drive/MyDrive/BRATS_2020/brats2020/BraTS2020_training_data/content/data/volume_70_slice_65.h5
#   inflating: /content/drive/MyDrive/BRATS_2020/brats2020/BraTS2020_training_data/content/data/volume_70_slice_66.h5
#   inflating: /content/drive/MyDrive/BRATS_2020/brats2020/BraTS2020_training_data/content/data/volume_70_slice_67.h5
#   inflating: /content/drive/MyDrive/BRATS_2020/brats2020/BraTS2020_training_data/content/data/volume_70_slice_68.h5
#   inflating: /content/drive/MyDrive/BRATS_2020/brats2020/BraTS2020_training_data/content/data/volume_70_slice_69.h5
#   inflating: /content/drive/MyDrive/BRATS_2020/brats2020/BraTS2020_training_data/content/data/volume_70_slice_7.h5
# ...

# %%
! pip install monai==1.1.0
